# %% [markdown]
# <a href="https://colab.research.google.com/github/bhallamohit18/Cypress1/blob/temp/RagFirst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
# !pip  install langchain_community langchainhub chromadb langchain langchain-openai
